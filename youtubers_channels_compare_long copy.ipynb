# %%
from googleapiclient.discovery import build
import pandas as pd
import numpy as np
from IPython.display import JSON
import isodate
import time
import requests

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.rcParams["font.size"]=14
matplotlib.rcParams["figure.figsize"]= (12,8)
matplotlib.rcParams["figure.facecolor"]="#00000000"

import seaborn as sns
sns.set_style("darkgrid")
sns.set(font="Verdana")
import plotly.express as px

# %%
#pip install flat-table --quiet  # for json_normalize with null value

# %%
import flat_table

# %%
api_key = 'AIzaSyB-PMZxmWNLPU4jwDaPwuxm1wCMO7SOrgo'

# %%
youtube = build("youtube", "v3", developerKey=api_key)

# %% [markdown]
# ## YouTube Video Categories

# %%
request = youtube.videoCategories().list(
        part="snippet",
        regionCode="US"
    )

response = request.execute()

# %%
yt_categories = pd.json_normalize(response["items"])

# %%
yt_categories.drop(columns=["kind","etag", "snippet.assignable","snippet.channelId"], inplace=True)
yt_categories.rename(columns={"id":"categoryId", "snippet.title":"category_title"}, inplace=True)

# %%
yt_categories
# Out:
#    categoryId         category_title
# 0           1       Film & Animation
# 1           2       Autos & Vehicles
# 2          10                  Music
# 3          15         Pets & Animals
# 4          17                 Sports
# 5          18           Short Movies
# 6          19        Travel & Events
# 7          20                 Gaming
# 8          21          Videoblogging
# 9          22         People & Blogs
# 10         23                 Comedy
# 11         24          Entertainment
# 12         25        News & Politics
# 13         26          Howto & Style
# 14         27              Education
# 15         28   Science & Technology
# 16         29  Nonprofits & Activism
# 17         30                 Movies
# 18         31        Anime/Animation
# 19         32       Action/Adventure
# 20         33               Classics
# 21         34                 Comedy
# 22         35            Documentary
# 23         36                  Drama
# 24         37                 Family
# 25         38                Foreign
# 26         39                 Horror
# 27         40         Sci-Fi/Fantasy
# 28         41               Thriller
# 29         42                 Shorts
# 30         43                  Shows
# 31         44               Trailers

# %%
yt_categories.to_csv("data/yt_categories.csv")

# %% [markdown]
# ## Get Channel Details

# %% [markdown]
# * https://developers.google.com/youtube/v3/docs/channels/list

# %%
def get_channel_info(channel_ids):
    request3 = youtube.channels().list(
        part="snippet,contentDetails, statistics",
        id=channel_ids
    )

    response3 = request3.execute()
    
    channel_cols_inner = ['channel_id','channel_name','channel_description','channel_publish',
                'country','playlist_uploadId','views','subscribers','videos']
    
    channel_df_inner = pd.DataFrame(columns=channel_cols_inner)
    
    channel_id          = response3["items"][0]["id"]
    channel_name        = response3["items"][0]["snippet"]["title"]
    channel_description = response3["items"][0]["snippet"]["description"]
    channel_publish     = response3["items"][0]["snippet"]["publishedAt"]
    country             = response3["items"][0]["snippet"]["country"]
    playlist_uploadId   = response3["items"][0]["contentDetails"]["relatedPlaylists"]["uploads"]
    views               = response3["items"][0]["statistics"]["viewCount"]
    subscribers         = response3["items"][0]["statistics"]["subscriberCount"]
    videos              = response3["items"][0]["statistics"]["videoCount"]

    channel_df_inner = channel_df_inner.append({
        "channel_id":channel_id,
        "channel_name":channel_name,
        "channel_description":channel_description,
        "channel_publish":channel_publish,
        "country":country,
        "playlist_uploadId":playlist_uploadId,
        "views":views,
        "subscribers":subscribers,
        "videos":videos},ignore_index=True)
    
    return(channel_df_inner)

# %% [markdown]
# ### Joma Tech | Channel Details

# %%
channel_ids_Joma = "UCV0qA-eDDICsRR9rPcnG7tw"

# %%
get_channel_info(channel_ids_Joma)
# Out:
#                  channel_id channel_name  \
# 0  UCV0qA-eDDICsRR9rPcnG7tw    Joma Tech
#
#                                  channel_description       channel_publish  \
# 0  I talk about life in Silicon Valley and at big...  2016-08-31T22:22:07Z
#
#   country         playlist_uploadId      views subscribers videos
# 0      US  UUV0qA-eDDICsRR9rPcnG7tw  124373921     1710000     99

# %%
channel_df_Joma = get_channel_info(channel_ids_Joma)

# %%
channel_df_Joma.to_csv("data/channel_df_Joma.csv")

# %% [markdown]
# ### Mayuko | Channel Details

# %%
channel_ids_Mayuko = "UCEDkO7wshcDZ7UZo17rPkzQ"

# %%
get_channel_info(channel_ids_Mayuko)
# Out:
#                  channel_id channel_name  \
# 0  UCEDkO7wshcDZ7UZo17rPkzQ       mayuko
#
#                                  channel_description       channel_publish  \
# 0  🌸a b o u t 🌸\nMayuko Inoue is a content creato...  2010-10-04T09:01:34Z
#
#   country         playlist_uploadId     views subscribers videos
# 0      US  UUEDkO7wshcDZ7UZo17rPkzQ  27052365      527000    161

# %%
channel_df_Mayuko = get_channel_info(channel_ids_Mayuko)

# %%
channel_df_Mayuko.to_csv("data/channel_df_Mayuko.csv")

# %% [markdown]
# ### Tina Huang | Channel Details

# %%
channel_ids_Tina = "UC2UXDak6o7rBm23k3Vv5dww"

# %%
get_channel_info(channel_ids_Tina)
# Out:
#                  channel_id channel_name  \
# 0  UC2UXDak6o7rBm23k3Vv5dww   Tina Huang
#
#                                  channel_description       channel_publish  \
# 0  Hi! My name is Tina and I'm a data scientist a...  2013-08-28T18:05:17Z
#
#   country         playlist_uploadId     views subscribers videos
# 0      US  UU2UXDak6o7rBm23k3Vv5dww  11086602      301000     94

# %%
channel_df_Tina = get_channel_info(channel_ids_Tina)

# %%
channel_df_Tina.to_csv("data/channel_df_Tina.csv")

# %% [markdown]
# ## Get Playlist_IDs

# %% [markdown]
# * https://developers.google.com/youtube/v3/docs/playlists/list
# * https://developers.google.com/youtube/v3/docs/playlistItems/list

# %%
def get_playlist_id(channel_ids):
    request = youtube.playlists().list(
        part="snippet,contentDetails",
        channelId = channel_ids, 
        maxResults = 50)
    response = request.execute()
    
    return(pd.json_normalize(response["items"]))

# %% [markdown]
# ### Joma | Playlist_IDs

# %%
playlist_df_Joma = get_playlist_id(channel_ids_Joma)
playlist_df_Joma.to_csv("data/playlist_df_Joma.csv")
playlist_df_Joma
# Out:
#                kind                         etag  \
# 0  youtube#playlist  HOJzoSR6lFHhamYFACthEM7OO0M
# 1  youtube#playlist  iQNCyw8heu3suPDGfyS4ftaj2mY
# 2  youtube#playlist  XKCp7LqXmXIEfNv8eC8djIAt3-w
# 3  youtube#playlist  8e_IxE6Senne6Pn56544Ft-QfsE
# 4  youtube#playlist  PIreM22A_mgxXqzSR_0_wSac01E
# 5  youtube#playlist  -MVFfRTikGueUzrk7Za3fw03V0A
# 6  youtube#playlist  Xz9R017meI2puOS5GjJ1PhdT1Lw
# 7  youtube#playlist  UEEmdOnQxblh7YVD9C8HghCDoBc
# 8  youtube#playlist  3-VBlg7QhO6nrXknv8yAbhSpmtQ
# 9  youtube#playlist  Jdgs11dQiyTHzMPzd_ZnlZi5u5s
#
#                                    id   snippet.publishedAt  \
# 0  PL0BAwa0pBqg58QavlD1MZ4oOEMBuv9VQp
# 2  https://i.ytimg.com/vi/IDdimFoqQ3s/maxresdefau...
# 3  https://i.ytimg.com/vi/xC-c7E5PK0Y/maxresdefau...
# 4  https://i.ytimg.com/vi/Hv6EMd8dlQk/maxresdefau...
# 5  https://i.ytimg.com/vi/uxRf7KS3abo/maxresdefau...
# 6                                                NaN
# 7  https://i.ytimg.com/vi/L1OZoY93qhk/maxresdefau...
# 8  https://i.ytimg.com/vi/02AXP5eI6PE/maxresdefau...
# 9  https://i.ytimg.com/vi/kZC12U6EhTc/maxresdefau...
#
#    snippet.thumbnails.maxres.width  snippet.thumbnails.maxres.height  \
# 0                           1280.0                             720.0
# 1                           1280.0                             720.0
# 2                           1280.0                             720.0
# 3                           1280.0                             720.0
# 4                           1280.0                             720.0
# 5                           1280.0                             720.0
# 6                              NaN                               NaN
# 7                           1280.0                             720.0
# 8                           1280.0                             720.0
# 9                           1280.0                             720.0
#
#   snippet.channelTitle                            snippet.localized.title  \
# 0            Joma Tech                            Joma Cinematic Universe
# 1            Joma Tech  Coding Interview Questions Video Explanation |...
# 2            Joma Tech  Vlogs and Bloopers 🍌 for Joma Plus Tier 3 Memb...
# 3            Joma Tech                      Data Science Analytics Videos
# 4            Joma Tech                     ► What to Watch | Best of Joma
# 5            Joma Tech                       Path to Software Engineering
# 6            Joma Tech                                         Interviews
# 7            Joma Tech                                              Vlogs
# 8            Joma Tech                                          Tech Show
# 9            Joma Tech                         Startup Series: 7 Episodes
#
#                        snippet.localized.description  contentDetails.itemCount
# 0  Joma Cinematic Universe (JCU) is a shared univ...                         8
# 1                                                                            1
# 2  I will be posting videos frequently for my Tie...                         6
# 3                                                                            8
# 4        New here? Start here for viewers' favorites                        13
# 5           Tips and tricks for Software Engineering                         7
# 6                                                                           16
# 7  Just me chilling in my daily life as a tech mo...                        18
# 8  Welcome to the Tech Show where we share tips a...                         6
# 9  Joma Startup: A mockumentary/vlog series inspi...                         7

# %% [markdown]
# ### Mayuko | Playlist_IDs

# %%
playlist_df_Mayuko = get_playlist_id(channel_ids_Mayuko)
playlist_df_Mayuko.to_csv("data/playlist_df_Mayuko.csv")
playlist_df_Mayuko
# Out:
#                kind                         etag  \
# 0  youtube#playlist  1ufo8pxZ43GSfY2xfU8on-Lfy_Y
# 1  youtube#playlist  GIiPymDZ9C7zTG3DT_c7hpxzqp0
# 2  youtube#playlist  JqcRGrUOPojatCpqUGgANfrJYWs
# 3  youtube#playlist  TC5Hs8oK5XU2FAkSqJIdXT9tMo4
# 4  youtube#playlist  0_dYRNS6f44DluKcgIFtlGpG06c
# 5  youtube#playlist  lIIaTA_OgBs6FRX_h-hcRGgA6y8
# 6  youtube#playlist  KGte0zyCPJmKftXQ7i8KVxgXqyY
# 7  youtube#playlist  _hb0jIb6Bes3vdxjsNiyOWCtDuk
# 8  youtube#playlist  X1XiVEwsJkGJ805oB6Fb0xz2S2w
# 9  youtube#playlist  tmX5D-FPdI9-khK7XWtZvOCmtH4
#
#                                    id   snippet.publishedAt  \
# 0  PL1hNTJtl-Vt4eDGeUeYU0Ur42gibtAom
#
#    snippet.thumbnails.maxres.width  snippet.thumbnails.maxres.height  \
# 0                           1280.0                             720.0
# 1                           1280.0                             720.0
# 2                           1280.0                             720.0
# 3                           1280.0                             720.0
# 4                              NaN                               NaN
# 5                           1280.0                             720.0
# 6                           1280.0                             720.0
# 7                              NaN                               NaN
# 8                           1280.0                             720.0
# 9                           1280.0                             720.0
#
#   snippet.channelTitle                            snippet.localized.title  \
# 0               mayuko                   🌟 Mayuko's Member's Only Show! 🌟
# 1               mayuko                                          🛠 tools 🛠
# 2               mayuko                                  💬 muko's corner 💬
# 3               mayuko                                           🖥 tech 🖥
# 4               mayuko                                           🌸 life 🌸
# 5               mayuko                                         🌱 health 🌱
# 6               mayuko                                         📈 career 📈
# 7               mayuko                                  🏆 greatest hits 🏆
# 8               mayuko  How to Kickstart Your Software Engineering Career
# 9               mayuko                                          🍵 vlogs 🍵
#
#                        snippet.localized.description  contentDetails.itemCount
# 0  A collection of exclusive videos just for my m...                         6
# 1                               my favorite things 😍                         8
# 2                                                                            9
# 3  explaining, playing with, and exploring techno...                        11
# 4        musings, ramblings, and peeks into my life.                         8
# 5  my thoughts on mental, physical, and emotional...                        12
# 6  advice I wish I had gotten throughout my tech ...                        14
# 7             the videos that are my pride and joy 💖                         6
# 8  Designed to help new folks coming into the tec...                        22
# 9  delivering a glimpse into my life, always with...                        19

# %% [markdown]
# ### Tina | Playlist_IDs

# %%
playlist_df_Tina = get_playlist_id(channel_ids_Tina)
playlist_df_Tina.to_csv("data/playlist_df_Tina.csv")
playlist_df_Tina
# Out:
#                kind                         etag  \
# 0  youtube#playlist  rPGW8yX8BFDk5cOwd7O1NLBxRDs
# 1  youtube#playlist  0ZIpT1OYhO6Oe-NXhg541xRnXIs
# 2  youtube#playlist  2c7RwUWGWgJR1W3yXOVUDuFnBq0
# 3  youtube#playlist  kjK4IZkhrDH8EERtZs4s0RZjljs
# 4  youtube#playlist  W-U0T_g-X4pwNwJcNTEcKxiTkcA
# 5  youtube#playlist  8y_dQHqoGM7WUDe-y0jFzNTvlSs
# 6  youtube#playlist  I9DmXWfi_hAXQQ_YwpuCiyYSC4c
# 7  youtube#playlist  siiOCJnwe4cOPTGp1qu0g9klPtQ
# 8  youtube#playlist  nPTPVsLiOM2CuDFGXSvVXmcwwa8
# 9  youtube#playlist  0aNQi3VvGsSVaJFw_L5IlysvBX4
#
#                                    id   snippet.publishedAt  \
# 0  PLVD3APpfd1tsfGXPWa8jb2UVc9GXJljeQ  2021-07-11T20:50:15Z
# 1  PLVD3APpfd1tutCd4Q9Q3_GOsqGs2r-I8
# 5  https://i.ytimg.com/vi/rd1HKwJT6GM/maxresdefau...
# 6  https://i.ytimg.com/vi/Td-cmLfQ7uU/maxresdefau...
# 7  https://i.ytimg.com/vi/2goqyY5XBeI/maxresdefau...
# 8  https://i.ytimg.com/vi/mueI-I7Suxw/maxresdefau...
# 9  https://i.ytimg.com/vi/QKqjV6L5VRY/maxresdefau...
#
#    snippet.thumbnails.maxres.width  snippet.thumbnails.maxres.height  \
# 0                           1280.0                             720.0
# 1                              NaN                               NaN
# 2                           1280.0                             720.0
# 3                           1280.0                             720.0
# 4                           1280.0                             720.0
# 5                           1280.0                             720.0
# 6                           1280.0                             720.0
# 7                           1280.0                             720.0
# 8                           1280.0                             720.0
# 9                           1280.0                             720.0
#
#   snippet.channelTitle                 snippet.localized.title  \
# 0           Tina Huang                                 trading
# 1           Tina Huang             self study and productivity
# 2           Tina Huang               study with me livestreams
# 3           Tina Huang                                Projects
# 4           Tina Huang                                   vlogs
# 5           Tina Huang                              MCIT UPenn
# 6           Tina Huang                             SQL Sundays
# 7           Tina Huang  How to Get Your First Data Science Job
# 8           Tina Huang      Resume Reviews (also asian snacks)
# 9           Tina Huang                                  Career
#
#                        snippet.localized.description  contentDetails.itemCount
# 0                                                                            1
# 1                                                                           26
# 2                                                                           41
# 3                                                                            3
# 4                                                                            2
# 5          Videos related to the MCIT UPenn program.                         6
# 6  Real data science SQL interview question walk ...                         9
# 7                                                                           11
# 8                                                                            4
# 9  Career related videos for data science, transi...                        42

# %% [markdown]
# ## Get Video_Ids

# %% [markdown]
# * **Needs playlist_ids to get video_ids**

# %%
pd.set_option("display.max_columns", 50)

# %%
def get_video_ids(list_of_playlist_ids):
    wanted_cols = ["channel_id", "playlist_id","video_id", "video_title", "video_description", "video_publish"]
    df = pd.DataFrame(columns=wanted_cols)             
    
    
    for j in range(len(list_of_playlist_ids)):
        
        request3 = youtube.playlistItems().list(
            part="snippet,contentDetails",
            playlistId=list_of_playlist_ids[j],
            maxResults = 50)
    
        response3 = request3.execute()
    
        for k in range(len(response3["items"])):
    
            channel_id   = response3["items"][k]["snippet"]["channelId"]
            playlist_id  = response3["items"][k]["snippet"]["playlistId"]
            video_title  = response3["items"][k]["snippet"]["title"]
            video_description = response3["items"][k]["snippet"]["description"]
            
            if len(response3["items"][k]["contentDetails"].keys()) == 1:
                video_id      =  response3["items"][k]["contentDetails"]["videoId"]
                video_publish = "NaN"
            else:
                video_id      =  response3["items"][k]["contentDetails"]["videoId"]
                video_publish = response3["items"][k]["contentDetails"]["videoPublishedAt"]
    
        
            df = df.append({"channel_id":channel_id,
                                              "playlist_id":playlist_id,
                                              "video_id":video_id,
                                              "video_title":video_title,
                                              "video_description":video_description,
                                              "video_publish":video_publish}, ignore_index=True)
    return(df)

# %% [markdown]
# ### Joma | List of Video_IDs

# %% [markdown]
# * **List of Playlist_Ids**

# %%
playlist_ids_list_Joma = list(playlist_df_Joma["id"][:])
playlist_ids_list_Joma
# Out:
# ['PL0BAwa0pBqg58QavlD1MZ4oOEMBuv9VQp',
#  'PL0BAwa0pBqg7tX6rxqz4sMM3z-JNaSTM8',
#  'PL0BAwa0pBqg57JkUQtH3Aejdv37S5FeAx',
#  'PL0BAwa0pBqg6dr_DfCL3DmeSLtFoAq7UR',
#  'PL0BAwa0pBqg7u7B8-MqWZPs8xvd7Y4umM',
#  'PL0BAwa0pBqg4HSDAvi4uELr9IRijItOkQ',
#  'PL0BAwa0pBqg7-SXpr9H_-89XI5i8SfJ7a',
#  'PL0BAwa0pBqg5XPzlwiGFfrNXHwGNBSTRc',
#  'PL0BAwa0pBqg5OGZ4kUHEDf2dlL0yN3oNC',
#  'PL0BAwa0pBqg6cgVi_N2arwjs6TQ6foPi7']

# %%
len(playlist_ids_list_Joma )
# Out:
# 10

# %% [markdown]
# * **List of Videos_Ids**

# %%
get_video_ids(playlist_ids_list_Joma)
# Out:
#                   channel_id                         playlist_id     video_id  \
# 0   UCV0qA-eDDICsRR9rPcnG7tw  PL0BAwa0pBqg58QavlD1MZ4oOEMBuv9VQp  Rgx8dpiPwpA
# 1   UCV0qA-eDDICsRR9rPcnG7tw  PL0BAwa0pBqg58QavlD1MZ4oOEMBuv9VQp  Hv6EMd8dlQk
# 2   UCV0qA-eDDICsRR9rPcnG7tw  PL0BAwa0pBqg58QavlD1MZ4oOEMBuv9VQp  YBYI7E2PqWE
# 3   UCV0qA-eDDICsRR9rPcnG7tw  PL0BAwa0pBqg58QavlD1MZ4oOEMBuv9VQp  TLysAkFM4cA
# 4   UCV0qA-eDDICsRR9rPcnG7tw  PL0BAwa0pBqg58QavlD1MZ4oOEMBuv9VQp  oCqkVZVPOe8
# ..                       ...                                 ...          ...
# 85  UCV0qA-eDDICsRR9rPcnG7tw  PL0BAwa0pBqg6cgVi_N2arwjs6TQ6foPi7  1-Iu__4R_b0
# 86  UCV0qA-eDDICsRR9rPcnG7tw  PL0BAwa0pBqg6cgVi_N2arwjs6TQ6foPi7  gTEHbBBl_dY
# 87  UCV0qA-eDDICsRR9rPcnG7tw  PL0BAwa0pBqg6cgVi_N2arwjs6TQ6foPi7  vX-QPzNppGY
# 88  UCV0qA-eDDICsRR9rPcnG7tw  PL0BAwa0pBqg6cgVi_N2arwjs6TQ6foPi7  RZsFHyKxir4
# 89  UCV0qA-eDDICsRR9rPcnG7tw  PL0BAwa0pBqg6cgVi_N2arwjs6TQ6foPi7  tgOLVIiI8WY
#
#                                           video_title  \
# 0   a day in the life of an engineer working from ...
# 1                      if Apple made window blinds...
# 2                If Squid Game were about Programmers
# 3   a day in the life of a startup engineer workin...
# 4                           crypto traders be like...
# ..                                                ...
# 85      Hiring My First Employees for my Tech Startup
# 86  Startup Software Engineers Build An MVP (Minim...
# 87   How Startups Deal With Competition And Marketing
# 88  Tech Startup Hires a Data Engineer To Grow The...
# 89           Learning How To Code to Build My Startup
#
#                                     video_description         video_publish
# 0   Check out my new vlog channel: https://www.you...  2021-05-23T06:15:41Z
# 1   Go to https://NordVPN.com/joma to get a 2-year...  2021-08-06T13:00:09Z
# 2   Go to https://NordVPN.com/joma to get 73% of t...  2021-11-26T06:14:53Z
# 3   Thanks to Logitech for sponsoring this video. ...  2021-12-15T15:48:55Z
# 4   If you want to be featured in my videos, you c...  2022-01-29T14:36:05Z
# ..                                                ...                   ...
# 85  Startup Episode 3\nNext Episode: https://www.y...  2018-02-01T17:00:01Z
# 86  Startup Episode 4\nNext Episode: https://www.y...  2018-03-01T17:00:03Z
# 87  Startup Episode 5\nNext Episode: https://www.y...  2018-04-01T16:00:05Z
# 88  Startup Episode 6\nNext Episode: https://www.y...  2018-06-02T07:23:10Z
# 89  Startup Episode 7\nWatch Bloopers: https://www...  2018-08-02T16:00:05Z
#
# [90 rows x 6 columns]

# %%
playlistIds_videoIds_Joma = get_video_ids(playlist_ids_list_Joma)
playlistIds_videoIds_Joma.to_csv("data/playlistIds_videoIds_Joma.csv")

# %% [markdown]
# ### Mayuko | | List of Video_IDs

# %% [markdown]
# * **List of Playlist_Ids**

# %%
playlist_ids_list_Mayuko = list(playlist_df_Mayuko["id"][:])
playlist_ids_list_Mayuko
# Out:
# ['PL1hNTJtl-Vt4eDGeUeYU0Ur42gibtAomo',
#  'PL1hNTJtl-Vt6Oc12S0FrYToR1x86sRqwf',
#  'PL1hNTJtl-Vt5gqtoLfjxonnz1j98lLqTM',
#  'PL1hNTJtl-Vt7RRfk-i-NbFihQ2jzbMeEx',
#  'PL1hNTJtl-Vt6VY_sYfgNj8TF-L0dd9BnI',
#  'PL1hNTJtl-Vt7_8E5L4JnWqDHGnahakVn5',
#  'PL1hNTJtl-Vt4DxHSRGpStuzFg8vciVDV3',
#  'PL1hNTJtl-Vt5FvEDenp4RbrNPPIZtJxwT',
#  'PL1hNTJtl-Vt5FGkgnfo3e0HjK-YPYCQzR',
#  'PL1hNTJtl-Vt7OCA0P8fwRVMgLCyc7zMsq']

# %% [markdown]
# * **List of Videos_Ids**

# %%
get_video_ids(playlist_ids_list_Mayuko)
# Out:
#                    channel_id                         playlist_id  \
# 0    UCEDkO7wshcDZ7UZo17rPkzQ  PL1hNTJtl-Vt4eDGeUeYU0Ur42gibtAomo
# 1    UCEDkO7wshcDZ7UZo17rPkzQ  PL1hNTJtl-Vt4eDGeUeYU0Ur42gibtAomo
# 2    UCEDkO7wshcDZ7UZo17rPkzQ  PL1hNTJtl-Vt4eDGeUeYU0Ur42gibtAomo
# 3    UCEDkO7wshcDZ7UZo17rPkzQ  PL1hNTJtl-Vt4eDGeUeYU0Ur42gibtAomo
# 4    UCEDkO7wshcDZ7UZo17rPkzQ  PL1hNTJtl-Vt4eDGeUeYU0Ur42gibtAomo
# ..                        ...                                 ...
# 110  UCEDkO7wshcDZ7UZo17rPkzQ  PL1hNTJtl-Vt7OCA0P8fwRVMgLCyc7zMsq
# 111  UCEDkO7wshcDZ7UZo17rPkzQ  PL1hNTJtl-Vt7OCA0P8fwRVMgLCyc7zMsq
# 112  UCEDkO7wshcDZ7UZo17rPkzQ  PL1hNTJtl-Vt7OCA0P8fwRVMgLCyc7zMsq
# 113  UCEDkO7wshcDZ7UZo17rPkzQ  PL1hNTJtl-Vt7OCA0P8fwRVMgLCyc7zMsq
# 114  UCEDkO7wshcDZ7UZo17rPkzQ  PL1hNTJtl-Vt7OCA0P8fwRVMgLCyc7zMsq
#
#         video_id                                        video_title  \
# 0    CgIVBER0gJo  How I Accepted my Job Offers for Intuit, Patre...
# 1    9tz1J09L_vg             Members Only Show: Writing cold emails
# 2    EQJhy-Xuey0  Should You Work with a Recruiting Agency to ge...
# 3    zsM1ASvV7PE                    Members Only Show: Resume Tips!
# 4    i26wnXQPN3s            helloMayuko Members Only Show: My HHKB!
# ..           ...                                                ...
# 110  tpeK8-AoL-A  Why we don't live in San Francisco, we learn h...
# 111  r11YBPUwQhk                          I made some life changes.
# 112  d-zI28wBIQQ  My first time speaking at a tech conference //...
# 113  a5GMRrEJaVo  a day in the life of a software engineer | wee...
# 114  rqX8PFcOpxA           a day in the life of a software engineer
#
#                                      video_description         video_publish
# 0    Thank you all for watching and being a member!...  2021-09-06T18:36:51Z
# 1    Thank you as always to my members and hope you...  2021-08-27T04:19:00Z
# 2    💖 m o r e  m a y u k o 💖\nBecome a member and ...  2021-08-18T18:06:52Z
# 3    Thank you always to my wonderful members and h...  2021-08-03T02:42:11Z
# 4    Thank you all so much for your continued suppo...  2021-07-28T03:14:27Z
# ..                                                 ...                   ...
# 110  This vlog was filmed in February 2020 (before ...  2020-04-10T22:05:18Z
# 111  Y'all, I've been pretty scared to post this vi...  2020-03-27T00:25:22Z
# 112  Oh, hi! Thanks for reading the description box...  2019-07-10T22:53:29Z
# 113  Hi!\n\nIt's been a long time since I did a vlo...  2018-02-26T06:05:20Z
# 114  … hi youtube\n\nhere’s my first video, giving ...  2017-07-17T21:52:10Z
#
# [115 rows x 6 columns]

# %%
playlistIds_videoIds_Mayuko = get_video_ids(playlist_ids_list_Mayuko)
playlistIds_videoIds_Mayuko.to_csv("data/playlistIds_videoIds_Mayuko.csv")

# %% [markdown]
# ### Tina| | List of Video_IDs

# %% [markdown]
# **List of_laylist_Ids**

# %%
playlist_ids_list_Tina = list(playlist_df_Tina["id"][:])
playlist_ids_list_Tina
# Out:
# ['PLVD3APpfd1tsfGXPWa8jb2UVc9GXJljeQ',
#  'PLVD3APpfd1tutCd4Q9Q3_GOsqGs2r-I8R',
#  'PLVD3APpfd1tsxl9cxYmwreJeHCVEC-lmx',
#  'PLVD3APpfd1tuZG0pek_JaPYRhGwpJj3Jd',
#  'PLVD3APpfd1tsceZeW_sh5QMPwlCxawJhx',
#  'PLVD3APpfd1ttpUNVJcYKh4P27malz0bLB',
#  'PLVD3APpfd1tuXrXBWAntLx4tNaONro5dA',
#  'PLVD3APpfd1tt1XPlGIwKr3apHsFc8yPOq',
#  'PLVD3APpfd1tthWsWOOSaZnEE61hMLFJgg',
#  'PLVD3APpfd1tv7CVfiv1NYdrlhXd5SU0wv']

# %% [markdown]
# * **List of Videos_Ids**

# %%
#get_video_ids(playlist_ids_list_Tina)
# Out:
#                    channel_id                         playlist_id  \
# 0    UC2UXDak6o7rBm23k3Vv5dww  PLVD3APpfd1tsfGXPWa8jb2UVc9GXJljeQ
# 1    UC2UXDak6o7rBm23k3Vv5dww  PLVD3APpfd1tutCd4Q9Q3_GOsqGs2r-I8R
# 2    UC2UXDak6o7rBm23k3Vv5dww  PLVD3APpfd1tutCd4Q9Q3_GOsqGs2r-I8R
# 3    UC2UXDak6o7rBm23k3Vv5dww  PLVD3APpfd1tutCd4Q9Q3_GOsqGs2r-I8R
# 4    UC2UXDak6o7rBm23k3Vv5dww  PLVD3APpfd1tutCd4Q9Q3_GOsqGs2r-I8R
# ..                        ...                                 ...
# 140  UC2UXDak6o7rBm23k3Vv5dww  PLVD3APpfd1tv7CVfiv1NYdrlhXd5SU0wv
# 141  UC2UXDak6o7rBm23k3Vv5dww  PLVD3APpfd1tv7CVfiv1NYdrlhXd5SU0wv
# 142  UC2UXDak6o7rBm23k3Vv5dww  PLVD3APpfd1tv7CVfiv1NYdrlhXd5SU0wv
# 143  UC2UXDak6o7rBm23k3Vv5dww  PLVD3APpfd1tv7CVfiv1NYdrlhXd5SU0wv
# 144  UC2UXDak6o7rBm23k3Vv5dww  PLVD3APpfd1tv7CVfiv1NYdrlhXd5SU0wv
#
#         video_id                                        video_title  \
# 0    5QfjIZb9rJM    How I'm learning to trade (forex swing trading)
# 1    yAwG8DoTmjI  How to self study using MOOCS (Udemy, Coursera...
# 2    doBZSrFxLeM                 How I stop myself from burning out
# 3    q6_9mdCkQhE  How I take notes - Tips for efficient note tak...
# 4    invk7t5YgcU  How I design effective study plans for ANY SUB...
# ..           ...                                                ...
# 140  vaD3ZFFNwhM  How to learn SQL for data science interview (t...
# 141  -zQ-Pf491bQ  How I Became a Data Scientist | Computer Scien...
# 142  Rx1i1J4m4MQ  How I got Software Engineering and Data Scienc...
# 143  KsQU_3n0IYE                           My UPenn MCIT Experience
# 144  JUkSeqe1eYQ  How to choose between software engineering and...
#
#                                      video_description         video_publish
# 0    In this video, I go through the details of my ...  2021-07-11T20:57:37Z
# 1    Hi friends! In this video, I go in depth on ho...  2021-05-27T17:00:20Z
# 2    Hi friends! I caught myself starting to burn o...  2021-06-18T18:00:49Z
# 3    Hi friends! In this video, I share with you gu...  2021-06-26T14:41:09Z
# 4    Hi friends! Self study is hard! It's hard to d...  2021-07-04T17:30:03Z
# ..                                                 ...                   ...
# 140  This is a step by step guide for how I learned...  2020-08-12T15:48:29Z
# 141  This is part 2 of my internship and job search...  2020-08-02T21:44:56Z
# 142  I got Amazon and Goldman Sachs internships for...  2020-07-28T16:48:31Z
# 143  I just graduated - yay! In this video, I talk ...  2020-07-17T04:53:01Z
# 144  Software Engineering vs Data Science? Last yea...  2020-07-22T06:00:57Z
#
# [145 rows x 6 columns]

# %%
playlistIds_videoIds_Tina = get_video_ids(playlist_ids_list_Tina)
playlistIds_videoIds_Tina.to_csv("data/playlistIds_videoIds_Tina.csv")

# %% [markdown]
# ## Get Videos Statistic

# %% [markdown]
# * **Needs Video_Id to get Video_Stat**

# %% [markdown]
# **Note: Private Videos**

# %%
playlistIds_videoIds_Joma[playlistIds_videoIds_Joma["video_publish"]=="NaN"]
# Out:
#                   channel_id                         playlist_id     video_id  \
# 13  UCV0qA-eDDICsRR9rPcnG7tw  PL0BAwa0pBqg57JkUQtH3Aejdv37S5FeAx  dwyJvMp6IJQ
# 38  UCV0qA-eDDICsRR9rPcnG7tw  PL0BAwa0pBqg4HSDAvi4uELr9IRijItOkQ  UtKDsGzULV8
# 66  UCV0qA-eDDICsRR9rPcnG7tw  PL0BAwa0pBqg5XPzlwiGFfrNXHwGNBSTRc  1DHj4uxPEpY
#
#       video_title       video_description video_publish
# 13  Private video  This video is private.           NaN
# 38  Private video  This video is private.           NaN
# 66  Private video  This video is private.           NaN

# %%
def get_videos_stat_raw(video_ids_list):
    
    wanted_cols3= ["video_id","publishedAt", "channelId","channelTitle", 
                   "title", "description","categoryId","duration","statistics"]
    videos_stat_raw = pd.DataFrame(columns=wanted_cols3)
    
    
    for i in range(len(video_ids_list)):
    
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=video_ids_list[i]
        )
        response = request.execute() 
    
    
        if len(response["items"]) != 0:
            
            video_id = response["items"][0]["id"]
            publishedAt = response["items"][0]["snippet"]["publishedAt"]
            channelId =   response["items"][0]["snippet"]["channelId"]
            channelTitle =response["items"][0]["snippet"]["channelTitle"]
            title =  response["items"][0]["snippet"]["title"]
            description = response["items"][0]["snippet"]["description"]
            categoryId = response["items"][0]["snippet"]["categoryId"]
        
            duration = response["items"][0]["contentDetails"]["duration"]
        
            statistics = response["items"][0]["statistics"]
        
        else:
            
            video_id = videos_ids_df["video_id"]
            publishedAt = None
            channelId = None
            channelTitle = None
            title = None
            description = None
            categoryId = None
            duration = None
            statistics = None
        
        videos_stat_raw  = videos_stat_raw.append({
                                     "video_id":video_id ,
                                     "publishedAt":publishedAt,
                                     "channelId":channelId,
                                     "channelTitle":channelTitle,
                                     "title":title,
                                     "description":description,
                                     "categoryId":categoryId,
                                     "duration":duration,
                                      "statistics":statistics
                                      }, ignore_index=True)
    return(videos_stat_raw)

# %%
def get_videos_stat_df(videos_df_raw):
    
    videos_df = flat_table.normalize(videos_df_raw)
        
    videos_df.rename(columns={"statistics.viewCount":"viewCount","statistics.likeCount":"likeCount",
                          "statistics.commentCount": "commentCount","statistics.favoriteCount":"favoriteCount" }, 
                          inplace=True)
    
    videos_df.drop(columns=["index"], axis=1, inplace=True)
        
    merged_df = videos_df.merge(yt_categories, on="categoryId")
        
    import isodate
    merged_df['durationSecs'] = merged_df['duration'].apply(lambda x: isodate.parse_duration(x))
    merged_df['durationSecs'] = merged_df['durationSecs'].astype('timedelta64[s]')
        
    merged_df = merged_df[['video_id','title','publishedAt','duration',"durationSecs",
                       'commentCount','favoriteCount','likeCount','viewCount',
                       'categoryId','category_title','channelId','channelTitle','description'                       
                          ]]
    return(merged_df)

# %% [markdown]
# ### Joma | Video Stat Details

# %%
videos_list_Joma = list(playlistIds_videoIds_Joma["video_id"])
len(videos_list_Joma)
# Out:
# 90

# %%
get_videos_stat_raw(videos_list_Joma)
# Out:
#        video_id           publishedAt                 channelId channelTitle  \
# 0   Rgx8dpiPwpA  2021-05-23T06:15:41Z  UCV0qA-eDDICsRR9rPcnG7tw    Joma Tech
# 1   Hv6EMd8dlQk  2021-08-06T13:00:09Z  UCV0qA-eDDICsRR9rPcnG7tw    Joma Tech
# 2   YBYI7E2PqWE  2021-11-26T06:14:53Z  UCV0qA-eDDICsRR9rPcnG7tw    Joma Tech
# 3   TLysAkFM4cA  2021-12-15T15:48:55Z  UCV0qA-eDDICsRR9rPcnG7tw    Joma Tech
# 4   oCqkVZVPOe8  2022-01-29T14:36:05Z  UCV0qA-eDDICsRR9rPcnG7tw    Joma Tech
# ..          ...                   ...                       ...          ...
# 85  1-Iu__4R_b0  2018-02-01T17:00:01Z  UCV0qA-eDDICsRR9rPcnG7tw    Joma Tech
# 86  gTEHbBBl_dY  2018-03-01T17:00:03Z  UCV0qA-eDDICsRR9rPcnG7tw    Joma Tech
# 87  vX-QPzNppGY  2018-04-01T16:00:05Z  UCV0qA-eDDICsRR9rPcnG7tw    Joma Tech
# 88  RZsFHyKxir4  2018-06-02T07:23:10Z  UCV0qA-eDDICsRR9rPcnG7tw    Joma Tech
# 89  tgOLVIiI8WY  2018-08-02T16:00:05Z  UCV0qA-eDDICsRR9rPcnG7tw    Joma Tech
#
#                                                 title  \
# 0   a day in the life of an engineer working from ...
# 1                      if Apple made window blinds...
# 2                If Squid Game were about Programmers
# 3   a day in the life of a startup engineer workin...
# 4                           crypto traders be like...
# ..                                                ...
# 85      Hiring My First Employees for my Tech Startup
# 86  Startup Software Engineers Build An MVP (Minim...
# 87   How Startups Deal With Competition And Marketing
# 88  Tech Startup Hires a Data Engineer To Grow The...
# 89           Learning How To Code to Build My Startup
#
#                                           description categoryId  duration  \
# 0   Check out my new vlog channel: https://www.you...         27   PT8M42S
# 1   Go to https://NordVPN.com/joma to get a 2-year...         27   PT8M16S
# 2   Go to https://NordVPN.com/joma to get 73% of t...         27   PT6M53S
# 3   Thanks to Logitech for sponsoring this video. ...         27   PT8M36S
# 4   If you want to be featured in my videos, you c...         24   PT6M44S
# ..                                                ...        ...       ...
# 85  Startup Episode 3\nNext Episode: https://www.y...         22   PT10M3S
# 86  Startup Episode 4\nNext Episode: https://www.y...         22  PT12M39S
# 87  Startup Episode 5\nNext Episode: https://www.y...         22  PT10M42S
# 88  Startup Episode 6\nNext Episode: https://www.y...         22  PT10M30S
# 89  Startup Episode 7\nWatch Bloopers: https://www...         22  PT13M35S
#
#                                            statistics
# 0   {'viewCount': '11959007', 'likeCount': '349444...
# 1   {'viewCount': '2323876', 'likeCount': '136279'...
# 2   {'viewCount': '867272', 'likeCount': '51024', ...
# 3   {'viewCount': '1475565', 'likeCount': '77496',...
# 4   {'viewCount': '1206914', 'likeCount': '68304',...
# ..                                                ...
# 85  {'viewCount': '615447', 'likeCount': '13898', ...
# 86  {'viewCount': '465934', 'likeCount': '11222', ...
# 87  {'viewCount': '253445', 'likeCount': '7072', '...
# 88  {'viewCount': '423976', 'likeCount': '10456', ...
# 89  {'viewCount': '338056', 'likeCount': '12417', ...
#
# [90 rows x 9 columns]

# %%
videos_df_raw_Joma = get_videos_stat_raw(videos_list_Joma)

# %%
get_videos_stat_df(videos_df_raw_Joma)
# Out:
#        video_id                                              title  \
# 0   Rgx8dpiPwpA  a day in the life of an engineer working from ...
# 1   Hv6EMd8dlQk                     if Apple made window blinds...
# 2   YBYI7E2PqWE               If Squid Game were about Programmers
# 3   TLysAkFM4cA  a day in the life of a startup engineer workin...
# 4   vmYaAzbv9xk  Data Scientists vs Data Engineers: Which one i...
# ..          ...                                                ...
# 82  vX-QPzNppGY   How Startups Deal With Competition And Marketing
# 83  RZsFHyKxir4  Tech Startup Hires a Data Engineer To Grow The...
# 84  tgOLVIiI8WY           Learning How To Code to Build My Startup
# 85  t6lBeG5QaC4        Interview with an iOS Engineer (ft. Mayuko)
# 86  t6lBeG5QaC4        Interview with an iOS Engineer (ft. Mayuko)
#
#              publishedAt  duration  durationSecs commentCount favoriteCount  \
# 0   2021-05-23T06:15:41Z   PT8M42S         522.0        11786             0
# 1   2021-08-06T13:00:09Z   PT8M16S         496.0         5191             0
# 2   2021-11-26T06:14:53Z   PT6M53S         413.0         1405             0
# 3   2021-12-15T15:48:55Z   PT8M36S         516.0         3600             0
# 4   2019-12-19T22:00:13Z   PT9M33S         573.0          388             0
# ..                   ...       ...           ...          ...           ...
# 82  2018-04-01T16:00:05Z  PT10M42S         642.0          338             0
# 83  2018-06-02T07:23:10Z  PT10M30S         630.0          525             0
# 84  2018-08-02T16:00:05Z  PT13M35S         815.0          821             0
# 85  2017-12-07T20:00:02Z  PT20M54S        1254.0          678             0
# 86  2017-12-07T20:00:02Z  PT20M54S        1254.0          678             0
#
#    likeCount viewCount categoryId        category_title  \
# 0     349444  11959007         27             Education
# 1     136279   2323876         27             Education
# 2      51024    867272         27             Education
# 3      77496   1475565         27             Education
# 4       7457    269819         27             Education
# ..       ...       ...        ...                   ...
# 82      7072    253445         22        People & Blogs
# 83     10456    423976         22        People & Blogs
# 84     12417    338056         22        People & Blogs
# 85     13938    719516         28  Science & Technology
# 86     13938    719516         28  Science & Technology
#
#                    channelId channelTitle  \
# 0   UCV0qA-eDDICsRR9rPcnG7tw    Joma Tech
# 1   UCV0qA-eDDICsRR9rPcnG7tw    Joma Tech
# 2   UCV0qA-eDDICsRR9rPcnG7tw    Joma Tech
# 3   UCV0qA-eDDICsRR9rPcnG7tw    Joma Tech
# 4   UCV0qA-eDDICsRR9rPcnG7tw    Joma Tech
# ..                       ...          ...
# 82  UCV0qA-eDDICsRR9rPcnG7tw    Joma Tech
# 83  UCV0qA-eDDICsRR9rPcnG7tw    Joma Tech
# 84  UCV0qA-eDDICsRR9rPcnG7tw    Joma Tech
# 85  UCV0qA-eDDICsRR9rPcnG7tw    Joma Tech
# 86  UCV0qA-eDDICsRR9rPcnG7tw    Joma Tech
#
#                                           description
# 0   Check out my new vlog channel: https://www.you...
# 1   Go to https://NordVPN.com/joma to get a 2-year...
# 2   Go to https://NordVPN.com/joma to get 73% of t...
# 3   Thanks to Logitech for sponsoring this video. ...
# 4   🐶 Join my Crypto Discord Server and be part of...
# ..                                                ...
# 82  Startup Episode 5\nNext Episode: https://www.y...
# 83  Startup Episode 6\nNext Episode: https://www.y...
# 84  Startup Episode 7\nWatch Bloopers: https://www...
# 85  🐶 Join my Crypto Discord Server and be part of...
# 86  🐶 Join my Crypto Discord Server and be part of...
#
# [87 rows x 14 columns]

# %%
videos_df_Joma = get_videos_stat_df(videos_df_raw_Joma)
videos_df_Joma.to_csv("data/videos_df_Joma.csv")

# %% [markdown]
# ### Mayuko  | Video Stat Detailstails

# %%
videos_list_Mayuko = list(playlistIds_videoIds_Mayuko["video_id"])
len(videos_list_Mayuko)
# Out:
# 115

# %%
get_videos_stat_raw(videos_list_Mayuko)
# Out:
#         video_id           publishedAt                 channelId channelTitle  \
# 0    CgIVBER0gJo  2021-09-06T18:36:51Z  UCEDkO7wshcDZ7UZo17rPkzQ       mayuko
# 1    9tz1J09L_vg  2021-08-27T04:19:00Z  UCEDkO7wshcDZ7UZo17rPkzQ       mayuko
# 2    EQJhy-Xuey0  2021-08-18T18:06:52Z  UCEDkO7wshcDZ7UZo17rPkzQ       mayuko
# 3    zsM1ASvV7PE  2021-08-03T02:42:11Z  UCEDkO7wshcDZ7UZo17rPkzQ       mayuko
# 4    i26wnXQPN3s  2021-07-28T03:14:27Z  UCEDkO7wshcDZ7UZo17rPkzQ       mayuko
# ..           ...                   ...                       ...          ...
# 110  tpeK8-AoL-A  2020-04-10T22:05:18Z  UCEDkO7wshcDZ7UZo17rPkzQ       mayuko
# 111  r11YBPUwQhk  2020-03-27T00:25:22Z  UCEDkO7wshcDZ7UZo17rPkzQ       mayuko
# 112  d-zI28wBIQQ  2019-07-10T22:53:29Z  UCEDkO7wshcDZ7UZo17rPkzQ       mayuko
# 113  a5GMRrEJaVo  2018-02-26T06:05:20Z  UCEDkO7wshcDZ7UZo17rPkzQ       mayuko
# 114  rqX8PFcOpxA  2017-07-17T21:52:10Z  UCEDkO7wshcDZ7UZo17rPkzQ       mayuko
#
#                                                  title  \
# 0    How I Accepted my Job Offers for Intuit, Patre...
# 1               Members Only Show: Writing cold emails
# 2    Should You Work with a Recruiting Agency to ge...
# 3                      Members Only Show: Resume Tips!
# 4              helloMayuko Members Only Show: My HHKB!
# ..                                                 ...
# 110  Why we don't live in San Francisco, we learn h...
# 111                          I made some life changes.
# 112  My first time speaking at a tech conference //...
# 113  a day in the life of a software engineer | wee...
# 114           a day in the life of a software engineer
#
#                                            description categoryId  duration  \
# 0    Thank you all for watching and being a member!...         22  PT10M50S
# 1    Thank you as always to my members and hope you...         22   PT5M55S
# 2    💖 m o r e  m a y u k o 💖\nBecome a member and ...         22   PT4M12S
# 3    Thank you always to my wonderful members and h...         22   PT8M36S
# 4    Thank you all so much for your continued suppo...         22   PT3M39S
# ..                                                 ...        ...       ...
# 110  This vlog was filmed in February 2020 (before ...         22   PT9M44S
# 111  Y'all, I've been pretty scared to post this vi...         22  PT12M45S
# 112  Oh, hi! Thanks for reading the description box...         22   PT8M15S
# 113  Hi!\n\nIt's been a long time since I did a vlo...         22   PT5M23S
# 114  … hi youtube\n\nhere’s my first video, giving ...         22   PT4M28S
#
#                                             statistics
# 0    {'likeCount': '29', 'favoriteCount': '0', 'com...
# 1    {'likeCount': '37', 'favoriteCount': '0', 'com...
# 2    {'likeCount': '20', 'favoriteCount': '0', 'com...
# 3    {'likeCount': '35', 'favoriteCount': '0', 'com...
# 4    {'likeCount': '25', 'favoriteCount': '0', 'com...
# ..                                                 ...
# 110  {'viewCount': '74674', 'likeCount': '1913', 'f...
# 111  {'viewCount': '312067', 'likeCount': '10565', ...
# 112  {'viewCount': '57630', 'likeCount': '1881', 'f...
# 113  {'viewCount': '478200', 'likeCount': '10811', ...
# 114  {'viewCount': '5262596', 'likeCount': '95501',...
#
# [115 rows x 9 columns]

# %%
videos_df_raw_Mayuko = get_videos_stat_raw(videos_list_Mayuko)

# %%
get_videos_stat_df(videos_df_raw_Mayuko)
# Out:
#         video_id                                              title  \
# 0    CgIVBER0gJo  How I Accepted my Job Offers for Intuit, Patre...
# 1    9tz1J09L_vg             Members Only Show: Writing cold emails
# 2    EQJhy-Xuey0  Should You Work with a Recruiting Agency to ge...
# 3    zsM1ASvV7PE                    Members Only Show: Resume Tips!
# 4    i26wnXQPN3s            helloMayuko Members Only Show: My HHKB!
# ..           ...                                                ...
# 110  tm0mF59f3jc  Dating After College with Chloe Shih // Muko's...
# 111  U-NXr5o42-M  Landing Your First Tech Job (Tips from an ex-F...
# 112  C-nReWYU6Xs  Belonging in Tech with Jordanna Kwok // Muko's...
# 113  7-VoOzbeWtU  How to Negotiate Your Tech Salary (with Sarah ...
# 114  sxCxcAdLGb0               Software developers going to therapy
#
#               publishedAt   duration  durationSecs commentCount favoriteCount  \
# 0    2021-09-06T18:36:51Z   PT10M50S         650.0           13             0
# 1    2021-08-27T04:19:00Z    PT5M55S         355.0            9             0
# 2    2021-08-18T18:06:52Z    PT4M12S         252.0            2             0
# 3    2021-08-03T02:42:11Z    PT8M36S         516.0            9             0
# 4    2021-07-28T03:14:27Z    PT3M39S         219.0           19             0
# ..                    ...        ...           ...          ...           ...
# 110  2021-04-09T01:41:13Z  PT1H7M46S        4066.0            2             0
# 111  2021-03-29T18:53:44Z  PT1H8M21S        4101.0            2             0
# 112  2021-03-09T02:18:09Z  PT1H12M5S        4325.0            0             0
# 113  2021-02-05T22:31:59Z     PT1H7M        4020.0           23             0
# 114  2019-09-19T22:00:12Z   PT28M42S        1722.0           14             0
#
#     likeCount viewCount categoryId        category_title  \
# 0          29       NaN         22        People & Blogs
# 1          37       NaN         22        People & Blogs
# 2          20       NaN         22        People & Blogs
# 3          35       NaN         22        People & Blogs
# 4          25       NaN         22        People & Blogs
# ..        ...       ...        ...                   ...
# 110       366       NaN         28  Science & Technology
# 111       339       NaN         28  Science & Technology
# 112       259       NaN         28  Science & Technology
# 113       694       NaN         28  Science & Technology
# 114       258     10997         28  Science & Technology
#
#                     channelId      channelTitle  \
# 0    UCEDkO7wshcDZ7UZo17rPkzQ            mayuko
# 1    UCEDkO7wshcDZ7UZo17rPkzQ            mayuko
# 2    UCEDkO7wshcDZ7UZo17rPkzQ            mayuko
# 3    UCEDkO7wshcDZ7UZo17rPkzQ            mayuko
# 4    UCEDkO7wshcDZ7UZo17rPkzQ            mayuko
# ..                        ...               ...
# 110  UCEDkO7wshcDZ7UZo17rPkzQ            mayuko
# 111  UCEDkO7wshcDZ7UZo17rPkzQ            mayuko
# 112  UCEDkO7wshcDZ7UZo17rPkzQ            mayuko
# 113  UCEDkO7wshcDZ7UZo17rPkzQ            mayuko
# 114  UCO1cgjhGzsSYb1rsB4bFe4Q  Fun Fun Function
#
#                                            description
# 0    Thank you all for watching and being a member!...
# 1    Thank you as always to my members and hope you...
# 2    💖 m o r e  m a y u k o 💖\nBecome a member and ...
# 3    Thank you always to my wonderful members and h...
# 4    Thank you all so much for your continued suppo...
# ..                                                 ...
# 110  In this episode of Muko's Corner, we're talkin...
# 111  In this episode of Muko's Corner, we're talkin...
# 112  In this episode of Muko's Corner, we'll talk a...
# 113  In this episode of Muko's Corner, we'll talk a...
# 114  💛 Brilliant (Episode sponsor)\nInteractive cou...
#
# [115 rows x 14 columns]

# %%
videos_df_Mayuko = get_videos_stat_df(videos_df_raw_Mayuko)
videos_df_Mayuko.to_csv("data/videos_df_Mayuko.csv")

# %% [markdown]
# ### Tina | Video Stat Details

# %%
videos_list_Tina = list(playlistIds_videoIds_Tina["video_id"])
len(videos_list_Tina)
# Out:
# 145

# %%
get_videos_stat_raw(videos_list_Tina)
# Out:
#         video_id           publishedAt                 channelId channelTitle  \
# 0    5QfjIZb9rJM  2021-07-11T20:57:37Z  UC2UXDak6o7rBm23k3Vv5dww   Tina Huang
# 1    yAwG8DoTmjI  2021-05-27T17:00:20Z  UC2UXDak6o7rBm23k3Vv5dww   Tina Huang
# 2    doBZSrFxLeM  2021-06-18T18:00:49Z  UC2UXDak6o7rBm23k3Vv5dww   Tina Huang
# 3    q6_9mdCkQhE  2021-06-26T14:41:09Z  UC2UXDak6o7rBm23k3Vv5dww   Tina Huang
# 4    invk7t5YgcU  2021-07-04T17:30:03Z  UC2UXDak6o7rBm23k3Vv5dww   Tina Huang
# ..           ...                   ...                       ...          ...
# 140  vaD3ZFFNwhM  2020-08-12T15:48:29Z  UC2UXDak6o7rBm23k3Vv5dww   Tina Huang
# 141  -zQ-Pf491bQ  2020-08-02T21:44:56Z  UC2UXDak6o7rBm23k3Vv5dww   Tina Huang
# 142  Rx1i1J4m4MQ  2020-07-28T16:48:31Z  UC2UXDak6o7rBm23k3Vv5dww   Tina Huang
# 143  KsQU_3n0IYE  2020-07-17T04:53:01Z  UC2UXDak6o7rBm23k3Vv5dww   Tina Huang
# 144  JUkSeqe1eYQ  2020-07-22T06:00:57Z  UC2UXDak6o7rBm23k3Vv5dww   Tina Huang
#
#                                                  title  \
# 0      How I'm learning to trade (forex swing trading)
# 1    How to self study using MOOCS (Udemy, Coursera...
# 2                   How I stop myself from burning out
# 3    How I take notes - Tips for efficient note tak...
# 4    How I design effective study plans for ANY SUB...
# ..                                                 ...
# 140  How to learn SQL for data science interview (t...
# 141  How I Became a Data Scientist | Computer Scien...
# 142  How I got Software Engineering and Data Scienc...
# 143                           My UPenn MCIT Experience
# 144  How to choose between software engineering and...
#
#                                            description categoryId  duration  \
# 0    In this video, I go through the details of my ...         27  PT17M32S
# 1    Hi friends! In this video, I go in depth on ho...         27  PT17M35S
# 2    Hi friends! I caught myself starting to burn o...         27   PT6M53S
# 3    Hi friends! In this video, I share with you gu...         27   PT10M2S
# 4    Hi friends! Self study is hard! It's hard to d...         27  PT13M46S
# ..                                                 ...        ...       ...
# 140  This is a step by step guide for how I learned...         28  PT10M27S
# 141  This is part 2 of my internship and job search...         28   PT7M52S
# 142  I got Amazon and Goldman Sachs internships for...         28   PT9M48S
# 143  I just graduated - yay! In this video, I talk ...         22  PT13M24S
# 144  Software Engineering vs Data Science? Last yea...         22   PT7M56S
#
#                                             statistics
# 0    {'viewCount': '29834', 'likeCount': '1170', 'f...
# 1    {'viewCount': '216461', 'likeCount': '8517', '...
# 2    {'viewCount': '24461', 'likeCount': '1334', 'f...
# 3    {'viewCount': '160721', 'likeCount': '7618', '...
# 4    {'viewCount': '59775', 'likeCount': '3341', 'f...
# ..                                                 ...
# 140  {'viewCount': '83352', 'likeCount': '5068', 'f...
# 141  {'viewCount': '12476', 'likeCount': '374', 'fa...
# 142  {'viewCount': '23755', 'likeCount': '804', 'fa...
# 143  {'viewCount': '15725', 'likeCount': '269', 'fa...
# 144  {'viewCount': '272617', 'likeCount': '12656', ...
#
# [145 rows x 9 columns]

# %%
videos_df_raw_Tina = get_videos_stat_raw(videos_list_Tina)

# %%
get_videos_stat_df(videos_df_raw_Tina)
# Out:
#         video_id                                              title  \
# 0    5QfjIZb9rJM    How I'm learning to trade (forex swing trading)
# 1    yAwG8DoTmjI  How to self study using MOOCS (Udemy, Coursera...
# 2    doBZSrFxLeM                 How I stop myself from burning out
# 3    q6_9mdCkQhE  How I take notes - Tips for efficient note tak...
# 4    invk7t5YgcU  How I design effective study plans for ANY SUB...
# ..           ...                                                ...
# 138  -zQ-Pf491bQ  How I Became a Data Scientist | Computer Scien...
# 139  Rx1i1J4m4MQ  How I got Software Engineering and Data Scienc...
# 140  KsQU_3n0IYE                           My UPenn MCIT Experience
# 141  KsQU_3n0IYE                           My UPenn MCIT Experience
# 142  JUkSeqe1eYQ  How to choose between software engineering and...
#
#               publishedAt  duration  durationSecs commentCount favoriteCount  \
# 0    2021-07-11T20:57:37Z  PT17M32S        1052.0          137             0
# 1    2021-05-27T17:00:20Z  PT17M35S        1055.0          252             0
# 2    2021-06-18T18:00:49Z   PT6M53S         413.0          152             0
# 3    2021-06-26T14:41:09Z   PT10M2S         602.0          242             0
# 4    2021-07-04T17:30:03Z  PT13M46S         826.0          142             0
# ..                    ...       ...           ...          ...           ...
# 138  2020-08-02T21:44:56Z   PT7M52S         472.0           41             0
# 139  2020-07-28T16:48:31Z   PT9M48S         588.0           64             0
# 140  2020-07-17T04:53:01Z  PT13M24S         804.0           72             0
# 141  2020-07-17T04:53:01Z  PT13M24S         804.0           72             0
# 142  2020-07-22T06:00:57Z   PT7M56S         476.0          596             0
#
#     likeCount viewCount categoryId        category_title  \
# 0        1170     29835         27             Education
# 1        8517    216461         27             Education
# 2        1334     24461         27             Education
# 3        7618    160721         27             Education
# 4        3341     59775         27             Education
# ..        ...       ...        ...                   ...
# 138       374     12476         28  Science & Technology
# 139       804     23755         28  Science & Technology
# 140       269     15725         22        People & Blogs
# 141       269     15725         22        People & Blogs
# 142     12656    272617         22        People & Blogs
#
#                     channelId channelTitle  \
# 0    UC2UXDak6o7rBm23k3Vv5dww   Tina Huang
# 1    UC2UXDak6o7rBm23k3Vv5dww   Tina Huang
# 2    UC2UXDak6o7rBm23k3Vv5dww   Tina Huang
# 3    UC2UXDak6o7rBm23k3Vv5dww   Tina Huang
# 4    UC2UXDak6o7rBm23k3Vv5dww   Tina Huang
# ..                        ...          ...
# 138  UC2UXDak6o7rBm23k3Vv5dww   Tina Huang
# 139  UC2UXDak6o7rBm23k3Vv5dww   Tina Huang
# 140  UC2UXDak6o7rBm23k3Vv5dww   Tina Huang
# 141  UC2UXDak6o7rBm23k3Vv5dww   Tina Huang
# 142  UC2UXDak6o7rBm23k3Vv5dww   Tina Huang
#
#                                            description
# 0    In this video, I go through the details of my ...
# 1    Hi friends! In this video, I go in depth on ho...
# 2    Hi friends! I caught myself starting to burn o...
# 3    Hi friends! In this video, I share with you gu...
# 4    Hi friends! Self study is hard! It's hard to d...
# ..                                                 ...
# 138  This is part 2 of my internship and job search...
# 139  I got Amazon and Goldman Sachs internships for...
# 140  I just graduated - yay! In this video, I talk ...
# 141  I just graduated - yay! In this video, I talk ...
# 142  Software Engineering vs Data Science? Last yea...
#
# [143 rows x 14 columns]

# %%
videos_df_Tina = get_videos_stat_df(videos_df_raw_Tina)
videos_df_Tina.to_csv("data/videos_df_Tina.csv")

# %% [markdown]
# ## Visualization

# %% [markdown]
# ### Split date Function

# %%
def date_split(df):
    df["publishedAt"] = pd.to_datetime(df["publishedAt"])
    df["year"] = df["publishedAt"].dt.year
    df["month"] = df["publishedAt"].dt.month
    df["day"] = df["publishedAt"].dt.day
    return(df)

# %% [markdown]
# ### Split Date & Fill NaN with 0

# %% [markdown]
# ### Joma

# %%
videos_df_Joma = pd.read_csv("data/videos_df_Joma.csv", index_col=0)
videos_df_Joma = date_split(videos_df_Joma)
videos_df_Joma.head(1)
# Out:
#       video_id                                              title  \
# 0  Rgx8dpiPwpA  a day in the life of an engineer working from ...
#
#                 publishedAt duration  durationSecs  commentCount  \
# 0 2021-05-23 06:15:41+00:00  PT8M42S         522.0         11786
#
#    favoriteCount  likeCount   viewCount  categoryId category_title  \
# 0              0     349444  11959007.0          27      Education
#
#                   channelId channelTitle  \
# 0  UCV0qA-eDDICsRR9rPcnG7tw    Joma Tech
#
#                                          description  year  month  day
# 0  Check out my new vlog channel: https://www.you...  2021      5   23

# %%
videos_df_Joma.tail(1)
# Out:
#        video_id                                        title  \
# 86  t6lBeG5QaC4  Interview with an iOS Engineer (ft. Mayuko)
#
#                  publishedAt  duration  durationSecs  commentCount  \
# 86 2017-12-07 20:00:02+00:00  PT20M54S        1254.0           678
#
#     favoriteCount  likeCount  viewCount  categoryId        category_title  \
# 86              0      13938   719516.0          28  Science & Technology
#
#                    channelId channelTitle  \
# 86  UCV0qA-eDDICsRR9rPcnG7tw    Joma Tech
#
#                                           description  year  month  day
# 86  🐶 Join my Crypto Discord Server and be part of...  2017     12    7

# %%
videos_df_Joma = videos_df_Joma.fillna(0)

# %% [markdown]
# ### Mayuko

# %%
videos_df_Mayuko = pd.read_csv("data/videos_df_Mayuko.csv", index_col=0)
videos_df_Mayuko = date_split(videos_df_Mayuko)

# %%
videos_df_Mayuko.head(1)
# Out:
#       video_id                                              title  \
# 0  CgIVBER0gJo  How I Accepted my Job Offers for Intuit, Patre...
#
#                 publishedAt  duration  durationSecs  commentCount  \
# 0 2021-09-06 18:36:51+00:00  PT10M50S         650.0            13
#
#    favoriteCount  likeCount  viewCount  categoryId  category_title  \
# 0              0         29        NaN          22  People & Blogs
#
#                   channelId channelTitle  \
# 0  UCEDkO7wshcDZ7UZo17rPkzQ       mayuko
#
#                                          description  year  month  day
# 0  Thank you all for watching and being a member!...  2021      9    6

# %%
videos_df_Mayuko.tail(1)
# Out:
#         video_id                                 title  \
# 114  sxCxcAdLGb0  Software developers going to therapy
#
#                   publishedAt  duration  durationSecs  commentCount  \
# 114 2019-09-19 22:00:12+00:00  PT28M42S        1722.0            14
#
#      favoriteCount  likeCount  viewCount  categoryId        category_title  \
# 114              0        258    10997.0          28  Science & Technology
#
#                     channelId      channelTitle  \
# 114  UCO1cgjhGzsSYb1rsB4bFe4Q  Fun Fun Function
#
#                                            description  year  month  day
# 114  💛 Brilliant (Episode sponsor)\nInteractive cou...  2019      9   19

# %%
videos_df_Mayuko = videos_df_Mayuko.fillna(0)

# %% [markdown]
# ### Tina

# %%
videos_df_Tina = pd.read_csv("data/videos_df_Tina.csv", index_col=0)
videos_df_Tina = date_split(videos_df_Tina)

# %%
videos_df_Tina.head(1)
# Out:
#       video_id                                            title  \
# 0  5QfjIZb9rJM  How I'm learning to trade (forex swing trading)
#
#                 publishedAt  duration  durationSecs  commentCount  \
# 0 2021-07-11 20:57:37+00:00  PT17M32S        1052.0           137
#
#    favoriteCount  likeCount  viewCount  categoryId category_title  \
# 0              0       1170      29835          27      Education
#
#                   channelId channelTitle  \
# 0  UC2UXDak6o7rBm23k3Vv5dww   Tina Huang
#
#                                          description  year  month  day
# 0  In this video, I go through the details of my ...  2021      7   11

# %%
videos_df_Tina.tail(1)
# Out:
#         video_id                                              title  \
# 142  JUkSeqe1eYQ  How to choose between software engineering and...
#
#                   publishedAt duration  durationSecs  commentCount  \
# 142 2020-07-22 06:00:57+00:00  PT7M56S         476.0           596
#
#      favoriteCount  likeCount  viewCount  categoryId  category_title  \
# 142              0      12656     272617          22  People & Blogs
#
#                     channelId channelTitle  \
# 142  UC2UXDak6o7rBm23k3Vv5dww   Tina Huang
#
#                                            description  year  month  day
# 142  Software Engineering vs Data Science? Last yea...  2020      7   22

# %%
videos_df_Tina = videos_df_Tina.fillna(0)

# %%
len(videos_df_Tina)
# Out:
# 143

# %% [markdown]
# ### Combine 3 DataFrames Together

# %%
len(videos_df_Joma) + len(videos_df_Mayuko) + len(videos_df_Tina)
# Out:
# 345

# %%
dfs = [videos_df_Joma,videos_df_Mayuko,videos_df_Tina]

# %%
all_youtubers_df = pd.concat(dfs)

# %%
len(all_youtubers_df)
# Out:
# 345

# %%
all_youtubers_df.head(2)
# Out:
#       video_id                                              title  \
# 0  Rgx8dpiPwpA  a day in the life of an engineer working from ...
# 1  Hv6EMd8dlQk                     if Apple made window blinds...
#
#                 publishedAt duration  durationSecs  commentCount  \
# 0 2021-05-23 06:15:41+00:00  PT8M42S         522.0         11786
# 1 2021-08-06 13:00:09+00:00  PT8M16S         496.0          5191
#
#    favoriteCount  likeCount   viewCount  categoryId category_title  \
# 0              0     349444  11959007.0          27      Education
# 1              0     136279   2323876.0          27      Education
#
#                   channelId channelTitle  \
# 0  UCV0qA-eDDICsRR9rPcnG7tw    Joma Tech
# 1  UCV0qA-eDDICsRR9rPcnG7tw    Joma Tech
#
#                                          description  year  month  day
# 0  Check out my new vlog channel: https://www.you...  2021      5   23
# 1  Go to https://NordVPN.com/joma to get a 2-year...  2021      8    6

# %%
#all_youtubers_df = all_youtubers_df.dropna()

# %%
#len(all_youtubers_df)

# %% [markdown]
# ### Channel Info

# %%
channel_df_Joma
# Out:
#                  channel_id channel_name  \
# 0  UCV0qA-eDDICsRR9rPcnG7tw    Joma Tech
#
#                                  channel_description       channel_publish  \
# 0  I talk about life in Silicon Valley and at big...  2016-08-31T22:22:07Z
#
#   country         playlist_uploadId      views subscribers videos
# 0      US  UUV0qA-eDDICsRR9rPcnG7tw  124373921     1710000     99

# %%
channel_df_Mayuko
# Out:
#                  channel_id channel_name  \
# 0  UCEDkO7wshcDZ7UZo17rPkzQ       mayuko
#
#                                  channel_description       channel_publish  \
# 0  🌸a b o u t 🌸\nMayuko Inoue is a content creato...  2010-10-04T09:01:34Z
#
#   country         playlist_uploadId     views subscribers videos
# 0      US  UUEDkO7wshcDZ7UZo17rPkzQ  27052365      527000    161

# %%
channel_df_Tina
# Out:
#                  channel_id channel_name  \
# 0  UC2UXDak6o7rBm23k3Vv5dww   Tina Huang
#
#                                  channel_description       channel_publish  \
# 0  Hi! My name is Tina and I'm a data scientist a...  2013-08-28T18:05:17Z
#
#   country         playlist_uploadId     views subscribers videos
# 0      US  UU2UXDak6o7rBm23k3Vv5dww  11086602      301000     94

# %%
channels = [channel_df_Joma, channel_df_Mayuko,channel_df_Tina]

# %%
channels_concat = pd.concat(channels)
channels_concat.to_csv("data/channels_concat.csv")
channels_concat
# Out:
#                  channel_id channel_name  \
# 0  UCV0qA-eDDICsRR9rPcnG7tw    Joma Tech
# 0  UCEDkO7wshcDZ7UZo17rPkzQ       mayuko
# 0  UC2UXDak6o7rBm23k3Vv5dww   Tina Huang
#
#                                  channel_description       channel_publish  \
# 0  I talk about life in Silicon Valley and at big...  2016-08-31T22:22:07Z
# 0  🌸a b o u t 🌸\nMayuko Inoue is a content creato...  2010-10-04T09:01:34Z
# 0  Hi! My name is Tina and I'm a data scientist a...  2013-08-28T18:05:17Z
#
#   country         playlist_uploadId      views subscribers videos
# 0      US  UUV0qA-eDDICsRR9rPcnG7tw  124373921     1710000     99
# 0      US  UUEDkO7wshcDZ7UZo17rPkzQ   27052365      527000    161
# 0      US  UU2UXDak6o7rBm23k3Vv5dww   11086602      301000     94

# %%
channels_concat = channels_concat.astype({"views":int,"subscribers":int, "videos":int})
#channels_concat.info()

# %%
fig, axes = plt.subplots(1,3 , figsize=(16,6))

axes[0].set_title("Subcribers", fontdict={"fontweight":"bold", "fontsize":14})
sns.barplot(ax=axes[0], y=channels_concat["subscribers"], x=channels_concat["channel_name"], palette="cool")

axes[1].set_title("Views", fontdict={"fontweight":"bold", "fontsize":14})
sns.barplot(ax=axes[1], y=channels_concat["views"],  x=channels_concat["channel_name"], palette="cool")


axes[2].set_title("Videos", fontdict={"fontweight":"bold", "fontsize":14})
sns.barplot(ax=axes[2], y=channels_concat["videos"], x=channels_concat["channel_name"], palette="cool")


plt.tight_layout(pad=2)

# %% [markdown]
# ### Number of Videos Publish Each Year

# %%
fig, axes = plt.subplots(1,3 , figsize=(16,6))

axes[0].set_title("Joma: Videos Each Year", fontdict={"fontweight":"bold", "fontsize":14})
sns.countplot(ax=axes[0], data = videos_df_Joma, x="year", palette="cool")

axes[1].set_title("Mayuko: Videos Each Year", fontdict={"fontweight":"bold", "fontsize":14})
sns.countplot(ax=axes[1], data = videos_df_Mayuko, x="year", palette="cool")


axes[2].set_title("Tina: Videos Each Year", fontdict={"fontweight":"bold", "fontsize":14})
sns.countplot(ax=axes[2], data = videos_df_Tina, x="year",palette="cool")


plt.tight_layout(pad=2)

# %% [markdown]
# ### Views Count

# %%
fig, axes = plt.subplots(1,3 , figsize=(16,6))

axes[0].set_title("Joma: Views Distribution", fontdict={"fontweight":"bold", "fontsize":14})
axes[0].set_ylabel("millions")
sns.violinplot(ax=axes[0], data = videos_df_Joma, y="viewCount", palette="cool")


axes[1].set_title("Mayuko: Views Distribution", fontdict={"fontweight":"bold", "fontsize":14})
sns.violinplot(ax=axes[1], data = videos_df_Mayuko, y="viewCount", palette="Blues")


axes[2].set_title("Tina: Views Distribution", fontdict={"fontweight":"bold", "fontsize":14})
sns.violinplot(ax=axes[2], data = videos_df_Tina, y="viewCount",palette="Greens")

plt.tight_layout(pad=2)

# %% [markdown]
# ### Likes Count

# %%
fig, axes = plt.subplots(1,3 , figsize=(16,6))

axes[0].set_title("Joma: Likes Distribution", fontdict={"fontweight":"bold", "fontsize":14})
axes[0].set_ylabel("millions")
sns.violinplot(ax=axes[0], data = videos_df_Joma, y="likeCount", palette="cool")


axes[1].set_title("Mayuko: Likes Distribution", fontdict={"fontweight":"bold", "fontsize":14})
sns.violinplot(ax=axes[1], data = videos_df_Mayuko, y="likeCount", palette="Blues")


axes[2].set_title("Tina: Likes Distribution", fontdict={"fontweight":"bold", "fontsize":14})
sns.violinplot(ax=axes[2], data = videos_df_Tina, y="likeCount",palette="Greens")

plt.tight_layout(pad=2)

# %% [markdown]
# ### Video Duration

# %%
fig, axes = plt.subplots(1,3 , figsize=(16,6))

axes[0].set_title("Joma: Video Duration", fontdict={"fontweight":"bold", "fontsize":14})
axes[0].set_ylabel("millions")
sns.violinplot(ax=axes[0], data = videos_df_Joma, y="durationSecs", palette="cool")


axes[1].set_title("Mayuko: Video Duration", fontdict={"fontweight":"bold", "fontsize":14})
sns.violinplot(ax=axes[1], data = videos_df_Mayuko, y="durationSecs", palette="Blues")


axes[2].set_title("Tina: Video Duration", fontdict={"fontweight":"bold", "fontsize":14})
sns.violinplot(ax=axes[2], data = videos_df_Tina, y="durationSecs",palette="Greens")

plt.tight_layout(pad=2)

# %% [markdown]
# ### Categories

# %%
fig, axes = plt.subplots(1,3 , figsize=(16,8))

axes[0].set_title("Joma: Videos Categories", fontdict={"fontweight":"bold", "fontsize":14})
axes[0].set_xticklabels("category_title", rotation = 90)
sns.countplot(ax=axes[0], data = videos_df_Joma, x="category_title", palette="cool")
              

axes[1].set_title("Mayuko: Videos Categories", fontdict={"fontweight":"bold", "fontsize":14})
axes[1].set_xticklabels("category_title", rotation = 90)
sns.countplot(ax=axes[1], data = videos_df_Mayuko, x="category_title", palette="cool")


axes[2].set_title("Tina: Videos Categories", fontdict={"fontweight":"bold", "fontsize":14})
axes[2].set_xticklabels("category_title", rotation = 90)
sns.countplot(ax=axes[2], data = videos_df_Tina, x="category_title",palette="cool")


plt.tight_layout(pad=3)
# Out:
# /var/folders/rk/_5r1csw96vn4r_l01g_prd_h0000gn/T/ipykernel_41735/1912044916.py:4: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator
#
# /var/folders/rk/_5r1csw96vn4r_l01g_prd_h0000gn/T/ipykernel_41735/1912044916.py:9: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator
#
# /var/folders/rk/_5r1csw96vn4r_l01g_prd_h0000gn/T/ipykernel_41735/1912044916.py:14: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator

# %% [markdown]
# ### Views & Length

# %%
all_youtubers_df.head(1)
# Out:
#       video_id                                              title  \
# 0  Rgx8dpiPwpA  a day in the life of an engineer working from ...
#
#                 publishedAt duration  durationSecs  commentCount  \
# 0 2021-05-23 06:15:41+00:00  PT8M42S         522.0         11786
#
#    favoriteCount  likeCount   viewCount  categoryId category_title  \
# 0              0     349444  11959007.0          27      Education
#
#                   channelId channelTitle  \
# 0  UCV0qA-eDDICsRR9rPcnG7tw    Joma Tech
#
#                                          description  year  month  day
# 0  Check out my new vlog channel: https://www.you...  2021      5   23

# %%
sns.scatterplot(data = all_youtubers_df, x = "durationSecs", y = "viewCount")
# Out:
# <AxesSubplot:xlabel='durationSecs', ylabel='viewCount'>

# %% [markdown]
# ### Views & Likes

# %%
sns.scatterplot(data = all_youtubers_df, y = "likeCount", x = "viewCount")
# Out:
# <AxesSubplot:xlabel='viewCount', ylabel='likeCount'>
